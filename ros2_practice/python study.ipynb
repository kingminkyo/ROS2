# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t= np.arange(0,6,0.01)
t

# %%
y=np.sin(np.pi* t)
y.shape
# Out:
# (600,)

# %%
plt.figure(figsize=(12,6))
plt.plot(t,y)
plt.grid()
#plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(t,y)
plt.grid()
plt.show()

# %%
class DrawSin:
    def __init__(self, amp, freq, bias, end_time) :
        self.amp = amp
        self.freq = freq
        self.bias = bias
        self.end_time = end_time
        
    def calc_sin(self):
        self.t = np.arange(0,self.end_time)

# %%
tmp = DrawSin(1,1,0,3)
tmp.__dict__
# Out:
# {'amp': 1, 'freq': 1, 'bias': 0, 'end_time': 3}
